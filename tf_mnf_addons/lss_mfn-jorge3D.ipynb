# %%
# !pip install classification-models-3D
# !pip install keras_applications
# !pip install volumentations-3D
from datetime import datetime

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#   # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
#   try:
#     tf.config.experimental.set_virtual_device_configuration(
#         gpus[0],
#         [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=7000)]) # Notice here
#     logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Virtual devices must be set before GPUs have been initialized
#     print(e)




from tqdm import tqdm
import sys
    # caution: path[0] is reserved for script path (or '' in REPL)
sys.path.insert(1, '/home/jupyter/tf-mnf')
from tf_mnf import models  # ,ROOT
#from tf_mnf.evaluate import rot_img
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
#from gpflow.utilities import print_summary
import pandas as pd
import os
#import dask.dataframe as dd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
#import tensorflow_hub as hub
from pathlib import Path,PurePath
import tensorflow_probability as tfp
tfd = tfp.distributions
tfb = tfp.bijectors
import zipfile
import glob
from tensorflow.keras.layers import Input,Conv3D, BatchNormalization,Dropout,LeakyReLU,Flatten,Dense,GlobalAveragePooling3D,MaxPooling3D,AveragePooling3D,GlobalMaxPool3D
from tensorflow.keras.regularizers import L2
from tensorflow.keras.models import Model
from tensorflow.keras import Sequential
from classification_models_3D.tfkeras import Classifiers
from volumentations import *
tfd = tfp.distributions
tfpl = tfp.layers
tfb = tfp.bijectors
tfk = tf.keras
RANDOM=123
gpus = tf.config.experimental.list_physical_devices('GPU')
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# from classification_models_3D.tfkeras import Classifiers

# ResNet18, preprocess_input = Classifiers.get('resnet18')
# model = ResNet18(input_shape=(128, 128, 128, 1), include_top=False,
#    weights=None)
# model.summary()

# %%
data = pd.read_csv('jorge/jorge/latin_hypercube_params.txt', sep="\s", header=0)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
data.head()
# Out:
#    index        Om         h    sigma8  fR0_scaled   fR0_sim
# 0      0  0.319057  0.621471  0.659495    0.567758  0.000002
# 1      1  0.225592  0.812328  0.717481    0.536195  0.000004
# 2      2  0.377067  0.533253  0.686238    0.418775  0.000065
# 3      3  0.167260  0.727625  0.884341    0.531757  0.000005
# 4      4  0.225614  0.810414  0.621485    0.437325  0.000042

# %%
data.describe()
# Out:
#             index           Om            h       sigma8   fR0_scaled  \
# count  2500.00000  2500.000000  2500.000000  2500.000000  2500.000000
# mean   1249.50000     0.304534     0.698586     0.802698     0.498826
# std     721.83216     0.115499     0.116635     0.115332     0.058121
# min       0.00000     0.100086     0.500186     0.600012     0.400071
# 25%     624.75000     0.204806     0.594697     0.702775     0.448074
# 50%    1249.50000     0.310886     0.696834     0.804256     0.498063
# 75%    1874.25000     0.402320     0.798831     0.899479     0.549520
# max    2499.00000     0.499873     0.899938     0.999838     0.599851
#
#            fR0_sim
# count  2500.000000
# mean      0.000022
# std       0.000026
# min       0.000001
# 25%       0.000003
# 50%       0.000010
# 75%       0.000033
# max       0.000100

# %%
array= np.arange(0,2500,1)
array
data['filename'] = array.tolist()

# %%
data.columns
# Out:
# Index(['index', 'Om', 'h', 'sigma8', 'fR0_scaled', 'fR0_sim', 'filename'], dtype='object')

# %%
from tf_mnf import models  # ,ROOT

# %%
#File_paths_64 = glob.glob('/content/drive/MyDrive/64_sim_quijote')
image_File_64=''
def omega_bh2(x):    
    return x["omega_b"] * x["h"]* x["h"] 
def omega_mh2(x):    
    return x["omega_m"] * x["h"]* x["h"]
def S8(x):    
    return x["sigma_8"] * (x["omega_m"]/0.3)**0.5

# %%
data['filename_path']=data.apply(
         lambda row: 'jorge/jorge/density_field_latin_hypercube/'+str(int(row.filename))+'/df_m_128_z=0.npy',axis=1)

# %%
data['filename_path']
# Out:
# 0       jorge/jorge/density_field_latin_hypercube/0/df...
# 1       jorge/jorge/density_field_latin_hypercube/1/df...
# 2       jorge/jorge/density_field_latin_hypercube/2/df...
# 3       jorge/jorge/density_field_latin_hypercube/3/df...
# 4       jorge/jorge/density_field_latin_hypercube/4/df...
#                               ...
# 2495    jorge/jorge/density_field_latin_hypercube/2495...
# 2496    jorge/jorge/density_field_latin_hypercube/2496...
# 2497    jorge/jorge/density_field_latin_hypercube/2497...
# 2498    jorge/jorge/density_field_latin_hypercube/2498...
# 2499    jorge/jorge/density_field_latin_hypercube/2499...
# Name: filename_path, Length: 2500, dtype: object

# %%
#num='_64'
#folder_anlysis='jorge/density_field_latin_hypercube/'#'/home/javier/Documents/quijote_notes/'

#data=pd.read_csv('/home/jupyter/latin_hypercube.csv')
#data['omega_bh2']=data.apply(omega_bh2, axis=1)
#data['omega_mh2']=data.apply(omega_mh2, axis=1)
#data['S8']=data.apply(S8, axis=1)
# run_diffs_apply = data['filename'].apply(
#          lambda row: Path(row).parts[0]+"/"+Path(row).parts[1].replace('_m_z', '_m{}_z'.format(num)))
# data['filename{}'.format(num)] = run_diffs_apply
filename_64=data['filename_path']
#filename_32=data['filename']
filename_names=['filename_path']
#"omega_b","sigma_8","h","n_s"]#["omega_m","omega_b","h","n_s","sigma_8"]
params=['Om', 'h', 'sigma8', 'fR0_scaled']
len_params=len(params)

# %%
removes=[]
def min_values(df,image_File):
     try:
         image=np.load(image_File+df,allow_pickle=True)
         min_val=image.min()
         return min_val
     except:
         print("Error! Could not load encoder for feature ", Path(df).parts[0])
         removes.append(int(Path(df).parts[0]))
         return None
def max_values(df,image_File):
     try:
         image=np.load(image_File+df,allow_pickle=True)
         max_val=image.max()
         return max_val
     #import pdb;pdb.set_trace()
     except:
         print("Error! Could not load encoder for feature ", Path(df).parts[0])
         return None

# %%
shuffle_data= data.sample(frac=1,random_state=RANDOM).reset_index(drop=True)
label_df=shuffle_data
Train_LSS_data, Test_LSS = train_test_split(label_df, test_size=0.2,random_state=RANDOM)
Train_LSS, Validation_LSS = train_test_split(Train_LSS_data, test_size=0.1,random_state=RANDOM)
Data_train_length =Train_LSS.shape[0]

# %%
shuffle_data
# Out:
#       index        Om         h    sigma8  fR0_scaled   fR0_sim  filename  \
# 0      2386  0.326215  0.703919  0.811267    0.417343  0.000067      2386
# 1      1298  0.349374  0.659167  0.605903    0.462941  0.000023      1298
# 2      1995  0.398515  0.591944  0.637442    0.412037  0.000076      1995
# 3      2097  0.478454  0.638831  0.908263    0.546926  0.000003      2097
# 4       289  0.171622  0.773584  0.959046    0.439274  0.000040       289
# ...     ...       ...       ...       ...         ...       ...       ...
# 2495   1147  0.360253  0.810617  0.959075    0.471844  0.000019      1147
# 2496   2154  0.276906  0.641261  0.930226    0.450494  0.000031      2154
# 2497   1766  0.155160  0.746843  0.700996    0.582037  0.000002      1766
# 2498   1122  0.157192  0.856196  0.947440    0.425997  0.000055      1122
# 2499   1346  0.457604  0.703919  0.948260    0.488152  0.000013      1346
#
#                                           filename_path
# 0     jorge/jorge/density_field_latin_hypercube/2386...
# 1     jorge/jorge/density_field_latin_hypercube/1298...
# 2     jorge/jorge/density_field_latin_hypercube/1995...
# 3     jorge/jorge/density_field_latin_hypercube/2097...
# 4     jorge/jorge/density_field_latin_hypercube/289/...
# ...                                                 ...
# 2495  jorge/jorge/density_field_latin_hypercube/1147...
# 2496  jorge/jorge/density_field_latin_hypercube/2154...
# 2497  jorge/jorge/density_field_latin_hypercube/1766...
# 2498  jorge/jorge/density_field_latin_hypercube/1122...
# 2499  jorge/jorge/density_field_latin_hypercube/1346...
#
# [2500 rows x 8 columns]

# %%
features= Train_LSS[params].values
num_feratures=len(params)
scaler = MinMaxScaler()
scaler.fit(features)
print(scaler.data_max_)
print(scaler.data_min_)
# Out:
# [0.49977939 0.89993787 0.99983828 0.59985074]
# [0.10018186 0.50018637 0.60001234 0.40007124]

# %%
removes=[]
min_val_64 = Train_LSS.filename_path.map(lambda x: min_values(x, image_File=image_File_64)).min()
max_val_64 = Train_LSS.filename_path.map(lambda x: max_values(x, image_File= image_File_64)).max()
data = data.drop(labels=removes, axis=0)

# %%
def normalization_data_32(array):
    thres=1.
    return 2*np.log(array-min_val_32+thres)/np.log(max_val_32-min_val_32+thres)-1./2#array
def normalization_data_64(array):
    thres=1.
    return 2*np.log(array-min_val_64+thres)/np.log(max_val_64-min_val_64+thres)-1./4.#array
    #return (array-min_val_64)/(max_val_64-min_val_64)#array

def normalization_features(feat):
    return (feat-scaler.data_min_)/(scaler.data_max_-scaler.data_min_)

def normalization_features_mean(feat):
  return feat*(scaler.data_max_-scaler.data_min_)+scaler.data_min_
def normalization_features_var(feat):
  return feat*(scaler.data_max_-scaler.data_min_)**2


def load_arrays(path,dim='32'):
  
  if dim=='32':
    image_ = np.load(image_File_32+path.numpy().decode())
    image =normalization_data_32(image_)
  else:
    image_ = np.load(image_File_64+path.numpy().decode())
    image =normalization_data_64(image_)
  #import pdb;pdb.set_trace()
  return image.reshape(image_.shape+(1,))

def tf_data_array(filenames1, features):
  [feat,]= tf.py_function(normalization_features, [features], [tf.float64])
  [image_64,] = tf.py_function(func= load_arrays,  inp=[filenames1,'64'], Tout=[tf.float64])
  image_64.set_shape(ma_64.shape+(1,))
  feat.set_shape(features.shape)
  return image_64,  feat

# %%
ma_64=np.load(image_File_64+filename_64[1])
plt.hist(normalization_data_64(ma_64.flatten()), bins='auto',color='red')
# Out:
# (array([2.7059e+04, 7.9010e+03, 7.9220e+03, 8.0300e+03, 8.3630e+03,
#         8.7070e+03, 9.0350e+03, 9.3820e+03, 9.9360e+03, 1.0193e+04,
#         1.0693e+04, 1.1144e+04, 1.1474e+04, 1.1836e+04, 1.2169e+04,
#         1.2654e+04, 1.3162e+04, 1.3567e+04, 1.3654e+04, 1.4140e+04,
#         1.4577e+04, 1.4921e+04, 1.5072e+04, 1.5454e+04, 1.5729e+04,
#         1.6060e+04, 1.6361e+04, 1.6726e+04, 1.6789e+04, 1.7568e+04,
#          1.02016401e+00,  1.02191842e+00,  1.02367282e+00,  1.02542710e+00,
#          1.02718151e+00,  1.02893591e+00,  1.03069019e+00,  1.03244460e+00,
#          1.03419900e+00,  1.03595340e+00,  1.03770769e+00,  1.03946209e+00,
#          1.04121649e+00,  1.04297078e+00,  1.04472518e+00,  1.04647958e+00,
#          1.04823399e+00,  1.04998827e+00,  1.05174267e+00,  1.05349708e+00,
#          1.05525148e+00,  1.05700576e+00,  1.05876017e+00,  1.06051457e+00,
#          1.06226885e+00,  1.06402326e+00,  1.06577766e+00,  1.06753206e+00,
#          1.06928635e+00,  1.07104075e+00,  1.07279515e+00,  1.07454956e+00,
#          1.07630384e+00,  1.07805824e+00,  1.07981265e+00,  1.08156693e+00,
#          1.08332133e+00,  1.08507574e+00,  1.08683014e+00,  1.08858442e+00,
#          1.09033883e+00,  1.09209323e+00,  1.09384751e+00,  1.09560192e+00,
#          1.09735632e+00,  1.09911072e+00,  1.10086501e+00,  1.10261941e+00,
#          1.10437381e+00,  1.10612822e+00,  1.10788250e+00,  1.10963690e+00,
#          1.11139131e+00,  1.11314559e+00,  1.11489999e+00,  1.11665440e+00,
#          1.11840880e+00,  1.12016308e+00,  1.12191749e+00,  1.12367189e+00,
#          1.12542629e+00,  1.12718058e+00,  1.12893498e+00,  1.13068938e+00,
#          1.13244367e+00,  1.13419807e+00,  1.13595247e+00,  1.13770688e+00,
#          1.13946116e+00,  1.14121556e+00,  1.14296997e+00,  1.14472425e+00,
#          1.14647865e+00,  1.14823306e+00,  1.14998746e+00,  1.15174174e+00,
#          1.15349615e+00,  1.15525055e+00,  1.15700495e+00,  1.15875924e+00,
#          1.16051364e+00,  1.16226804e+00,  1.16402233e+00,  1.16577673e+00,
#          1.16753113e+00,  1.16928554e+00,  1.17103982e+00,  1.17279422e+00,
#          1.17454863e+00,  1.17630291e+00,  1.17805731e+00,  1.17981172e+00,
#          1.18156612e+00,  1.18332040e+00,  1.18507481e+00,  1.18682921e+00,
#          1.18858361e+00,  1.19033790e+00,  1.19209230e+00,  1.19384670e+00,
#          1.19560099e+00,  1.19735539e+00,  1.19910979e+00,  1.20086420e+00,
#          1.20261848e+00,  1.20437288e+00,  1.20612729e+00,  1.20788169e+00,
#          1.20963597e+00,  1.21139038e+00,  1.21314478e+00,  1.21489906e+00,
#          1.21665347e+00,  1.21840787e+00,  1.22016227e+00,  1.22191656e+00,
#          1.22367096e+00,  1.22542536e+00,  1.22717965e+00,  1.22893405e+00,
#          1.23068845e+00,  1.23244286e+00,  1.23419714e+00,  1.23595154e+00,
#          1.23770595e+00,  1.23946035e+00,  1.24121463e+00,  1.24296904e+00],
#        dtype=float32),
#  <BarContainer object of 851 artists>)

# %%
ma_64.shape
# Out:
# (128, 128, 128)

# %%
BATCH_SIZE=8
def datasets_iteration(dataset_row,files_mod, training=True):
    filename_64=dataset_row[files_mod[0]]
    features=dataset_row[params].values
    dataset = tf.data.Dataset.from_tensor_slices((filename_64,features))
    print(dataset)
    if training:
        dataset =dataset.shuffle(len(dataset_row),seed=RANDOM)
    dataset = dataset.map(tf_data_array).batch(BATCH_SIZE)
    return dataset

# %%
Train_dataset= datasets_iteration(Train_LSS,filename_names)
Validation_dataset= datasets_iteration(Validation_LSS,filename_names)
Test_dataset= datasets_iteration(Test_LSS,filename_names,False)
for i,j in Train_dataset.take(1):
    print(i.shape,j.shape)
Train_dataset
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(4,), dtype=tf.float64, name=None))>
# <TensorSliceDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(4,), dtype=tf.float64, name=None))>
# <TensorSliceDataset element_spec=(TensorSpec(shape=(), dtype=tf.string, name=None), TensorSpec(shape=(4,), dtype=tf.float64, name=None))>
# (8, 128, 128, 128, 1) (8, 4)
# <BatchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 128, 1), dtype=tf.float64, name=None), TensorSpec(shape=(None, 4), dtype=tf.float64, name=None))>

# %%
beta = tf.Variable(1.0)
beta._trainable = False
def warmup(epoch):
    value = (epoch/10.0) * (epoch <= 10.0) + 1.0 * (epoch > 10.0)
    #print("beta:", value)
    #tf.keras.backend.set_value(beta, value)
from tensorflow.keras.callbacks import LambdaCallback
wu_cb = LambdaCallback(on_epoch_end=lambda epoch, log: warmup(epoch))

# %%
import datetime
logdir = "tf-mnf/tfboard_logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
file_writer = tf.summary.create_file_writer(logdir + "/metrics")
file_writer.set_as_default()

# %%
#del[mnf_lenet]
mnf_lenet = models.MNFLeNet3DResnet(model_name='resnet18',n_classes=len_params,pooling='avg')


# %%
# We minimize the negative log-likelihood, i.e. maximize the log-likelihood of
# observed data (X_train, y_train) under the model
def loss_fn(labels, preds):
    # entropic_loss = multiclass cross entropy = negative log-likelihood.
    #cross_entropy = tf.keras.losses.MeanSquaredError()(labels, preds)
    cross_entropy = -preds.log_prob(labels)
    entropic_loss = tf.reduce_mean(cross_entropy)
    # The weighting factor dividing the KL divergence can be used as a hyperparameter.
    # Decreasing it makes learning more difficult but prevents model overfitting. If
    # not seen as hyperparameter, it should be applied once per epoch, i.e. divided by
    # the number of samples in one epoch.
    kl_loss = mnf_lenet.kl_div() / Data_train_length
    loss = entropic_loss + beta * kl_loss

    tf.summary.scalar("negative log-likelihood", entropic_loss,step=Data_train_length//BATCH_SIZE)
    tf.summary.scalar("KL divergence_times_beta",  beta* kl_loss,step=Data_train_length//BATCH_SIZE)
    tf.summary.scalar("KL divergence",  kl_loss,step=Data_train_length//BATCH_SIZE)
    tf.summary.scalar("KL divergence",  beta,step=Data_train_length//BATCH_SIZE)
    tf.summary.scalar("loss", loss,step=Data_train_length//BATCH_SIZE)

    return loss

# %%
epochs=50*5
adam = tf.optimizers.Adam(3e-3)
##mnf_lenet.compile(loss=loss_fn, optimizer=adam, metrics=["mse"])

# %%
#mnf_lenet.summary()

# %%
# %%
#epochs=50*3
#adam = tf.optimizers.Adam(5e-5)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min' ,factor=0.8,verbose=1,
                              patience=5, min_lr=1e-7)
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15,mode='min',restore_best_weights=True,
)
##'tf-mnf/logs/checkpoint' este es el mejor.
checkpoint_filepath = 'tf-mnf/logs/checkpointnew'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_mse',
    mode='min',
    save_best_only=True)


mnf_lenet.compile(loss=loss_fn, optimizer=adam, metrics=["mse"])
#mnf_lenet.load_weights('tf-mnf/logs/checkpointsenet')


mnf_hist = mnf_lenet.fit(
     Train_dataset, epochs=epochs,
           validation_data=Validation_dataset,  callbacks=[reduce_lr,callback,wu_cb,model_checkpoint_callback],verbose=1)
# Out:
# Epoch 1/250
# 2023-08-04 02:34:23.332124: I tensorflow/core/grappler/optimizers/generic_layout_optimizer.cc:370] Cancel Transpose nodes around Pad: transpose_before=mnf_le_net3d_resnet/batch_normalization/FusedBatchNormV3-0-1-TransposeNCDHWToNDHWC-LayoutOptimizer pad=mnf_le_net3d_resnet/zero_padding3d_18/Pad transpose_after=mnf_le_net3d_resnet/mnf_conv3d/Conv3D-0-TransposeNDHWCToNCDHW-LayoutOptimizer,gradient_tape/mnf_le_net3d_resnet/mnf_conv3d/Conv3DBackpropFilterV2-0-TransposeNDHWCToNCDHW-LayoutOptimizer,gradient_tape/mnf_le_net3d_resnet/mnf_conv3d/Shape-0-TransposeNDHWCToNCDHW-LayoutOptimizer,mnf_le_net3d_resnet/mnf_conv3d/Square_1-0-TransposeNDHWCToNCDHW-LayoutOptimizer,gradient_tape/mnf_le_net3d_resnet/mnf_conv3d/Mul_1-1-TransposeNDHWCToNCDHW-LayoutOptimizer
# 2023-08-04 02:34:44.506723: W tensorflow/core/common_runtime/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 128.00MiB (rounded to 134217728)requested by op SameWorkerRecvDone
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-08-04 02:34:44.506838: I tensorflow/core/common_runtime/bfc_allocator.cc:1033] BFCAllocator dump for GPU_0_bfc
# 2023-08-04 02:34:44.506855: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (256): 	Total Chunks: 1300, Chunks in use: 1300. 325.0KiB allocated for chunks. 325.0KiB in use in bin. 157.7KiB client-requested in use in bin.
# 2023-08-04 02:34:44.506864: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (512): 	Total Chunks: 247, Chunks in use: 247. 124.2KiB allocated for chunks. 124.2KiB in use in bin. 123.5KiB client-requested in use in bin.
# 2023-08-04 02:34:44.506871: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (1024): 	Total Chunks: 112, Chunks in use: 112. 115.8KiB allocated for chunks. 115.8KiB in use in bin. 114.4KiB client-requested in use in bin.
# 2023-08-04 02:34:44.506879: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (2048): 	Total Chunks: 120, Chunks in use: 120. 361.0KiB allocated for chunks. 361.0KiB in use in bin. 346.5KiB client-requested in use in bin.
# 2023-08-04 02:34:44.506886: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (4096): 	Total Chunks: 197, Chunks in use: 197. 1.18MiB allocated for chunks. 1.18MiB in use in bin. 1.16MiB client-requested in use in bin.
# 2023-08-04 02:34:44.506893: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (8192): 	Total Chunks: 173, Chunks in use: 173. 2.08MiB allocated for chunks. 2.08MiB in use in bin. 2.04MiB client-requested in use in bin.
# 2023-08-04 02:34:44.506900: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (16384): 	Total Chunks: 214, Chunks in use: 214. 5.21MiB allocated for chunks. 5.21MiB in use in bin. 5.17MiB client-requested in use in bin.
# 2023-08-04 02:34:44.506907: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (32768): 	Total Chunks: 109, Chunks in use: 109. 5.21MiB allocated for chunks. 5.21MiB in use in bin. 5.19MiB client-requested in use in bin.
# 2023-08-04 02:34:44.506914: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (65536): 	Total Chunks: 23, Chunks in use: 23. 2.36MiB allocated for chunks. 2.36MiB in use in bin. 2.20MiB client-requested in use in bin.
# 2023-08-04 02:34:44.506920: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (131072): 	Total Chunks: 8, Chunks in use: 8. 1.60MiB allocated for chunks. 1.60MiB in use in bin. 1.60MiB client-requested in use in bin.
# 2023-08-04 02:34:44.506927: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (262144): 	Total Chunks: 23, Chunks in use: 23. 9.53MiB allocated for chunks. 9.53MiB in use in bin. 9.53MiB client-requested in use in bin.
# 2023-08-04 02:34:44.506934: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (524288): 	Total Chunks: 10, Chunks in use: 10. 8.13MiB allocated for chunks. 8.13MiB in use in bin. 7.67MiB client-requested in use in bin.
# 2023-08-04 02:34:44.506941: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (1048576): 	Total Chunks: 22, Chunks in use: 22. 37.12MiB allocated for chunks. 37.12MiB in use in bin. 37.12MiB client-requested in use in bin.
# 2023-08-04 02:34:44.506948: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (2097152): 	Total Chunks: 1, Chunks in use: 1. 3.38MiB allocated for chunks. 3.38MiB in use in bin. 3.38MiB client-requested in use in bin.
# 2023-08-04 02:34:44.506956: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (4194304): 	Total Chunks: 4, Chunks in use: 3. 26.56MiB allocated for chunks. 20.25MiB in use in bin. 20.25MiB client-requested in use in bin.
# 2023-08-04 02:34:44.506963: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (8388608): 	Total Chunks: 1, Chunks in use: 1. 13.50MiB allocated for chunks. 13.50MiB in use in bin. 13.50MiB client-requested in use in bin.
# 2023-08-04 02:34:44.506972: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (16777216): 	Total Chunks: 3, Chunks in use: 3. 81.00MiB allocated for chunks. 81.00MiB in use in bin. 81.00MiB client-requested in use in bin.
# 2023-08-04 02:34:44.506979: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-08
I tensorflow/core/grappler/optimizers/generic_layout_optimizer.cc:370] Cancel Transpose nodes around Pad: transpose_before=mnf_le_net3d_resnet/batch_normalization/FusedBatchNormV3-0-0-TransposeNCDHWToNDHWC-LayoutOptimizer pad=mnf_le_net3d_resnet/zero_padding3d_18/Pad transpose_after=mnf_le_net3d_resnet/mnf_conv3d/Conv3D-0-TransposeNDHWCToNCDHW-LayoutOptimizer,mnf_le_net3d_resnet/mnf_conv3d/Square_1-0-TransposeNDHWCToNCDHW-LayoutOptimizer,mnf_le_net3d_resnet/mnf_conv3d/Shape-0-TransposeNDHWCToNCDHW-LayoutOptimizer
# 2023-08-03 05:41:34.811147: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8200
#  1/63 [..............................] - ETA: 22:36 - loss: 4631.7993 - mse: 0.7342
# 2023-08-03 05:41:35.889528: I tensorflow/core/util/cuda_solvers.cc:179] Creating GpuSolver handles for stream 0x564d0bddfce0
# 63/63 [==============================] - 134s 2s/step - loss: 4632.1084 - mse: 0.7949
# [4632.1083984375, 0.7948899865150452]

# %%
predictions=mnf_lenet.predict(Test_dataset)
# Out:
# 2023-08-03 05:49:27.687017: I tensorflow/core/grappler/optimizers/generic_layout_optimizer.cc:370] Cancel Transpose nodes around Pad: transpose_before=mnf_le_net3d_resnet_2/batch_normalization_54/FusedBatchNormV3-0-0-TransposeNCDHWToNDHWC-LayoutOptimizer pad=mnf_le_net3d_resnet_2/zero_padding3d_38/Pad transpose_after=mnf_le_net3d_resnet_2/mnf_conv3d_58/Conv3D-0-TransposeNDHWCToNCDHW-LayoutOptimizer,mnf_le_net3d_resnet_2/mnf_conv3d_58/Square_1-0-TransposeNDHWCToNCDHW-LayoutOptimizer,mnf_le_net3d_resnet_2/mnf_conv3d_58/Shape-0-TransposeNDHWCToNCDHW-LayoutOptimizer
# 2023-08-03 05:49:29.610117: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8200
# 63/63 [==============================] - 32s 398ms/step

# %%
predictions.shape
# Out:
# (500, 4)

# %%
x_image_total=[]
y_total=[]
for x, y in Test_dataset:
    x_image= mnf_lenet.predict(x)
    x_image_total.append(x_image)
    y_total.append(y)
#print(x.shape,y.shape)
# Out:
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 2s 2s/step

# %%
prediction=np.concatenate(x_image_total,axis=0)
ytrue=np.concatenate(y_total,axis=0)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
r2_score(ytrue,prediction,multioutput='raw_values')
# Out:
# array([ 0.60435815, -0.76717453,  0.75837394, -0.91688678])

# %%
mean_squared_error(ytrue,prediction,multioutput='raw_values')
# Out:
# array([0.03429424, 0.14930875, 0.02046996, 0.1559954 ])

# %%
mnf_lenet.evaluate(Test_dataset)
# Out:
# 2023-07-16 23:25:06.378826: I tensorflow/core/grappler/optimizers/generic_layout_optimizer.cc:370] Cancel Transpose nodes around Pad: transpose_before=mnf_le_net3d_resnet/batch_normalization/FusedBatchNormV3-0-0-TransposeNCDHWToNDHWC-LayoutOptimizer pad=mnf_le_net3d_resnet/zero_padding3d_18/Pad transpose_after=mnf_le_net3d_resnet/mnf_conv3d/Conv3D-0-TransposeNDHWCToNCDHW-LayoutOptimizer,mnf_le_net3d_resnet/mnf_conv3d/Square_1-0-TransposeNDHWCToNCDHW-LayoutOptimizer,mnf_le_net3d_resnet/mnf_conv3d/Shape-0-TransposeNDHWCToNCDHW-LayoutOptimizer
# 2023-07-16 23:25:11.413834: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8200
#  1/63 [..............................] - ETA: 33:09 - loss: -99.4532 - mse: 0.1157
# 2023-07-16 23:25:12.877498: I tensorflow/core/util/cuda_solvers.cc:179] Creating GpuSolver handles for stream 0x55e47b7d2e50
# 63/63 [==============================] - 59s 438ms/step - loss: -99.2986 - mse: 0.0926
# [-99.29862976074219, 0.09264963120222092]

# %%
mnf_lenet.evaluate(Test_dataset)
# Out:
# 125/125 [==============================] - 142s 1s/step - loss: -3.3816 - mse: 0.0938
# [-3.381575107574463, 0.09383955597877502]

# %%
mnf_lenet.save_weights('save_models_jorge2/modelmnfresnet18a')

# %%
mnf_lenet.load_weights('save_models_jorge2/modelmnfresnet18a')
mnf_lenet.evaluate(Test_dataset)
# Out:
# 125/125 [==============================] - 32s 259ms/step - loss: -3.3424 - mse: 0.0902
# [-3.342449426651001, 0.09015525877475739]

# %%
from classification_models_3D.tfkeras import Classifiers
from volumentations import *
ResNet18a, preprocess_input = Classifiers.get('resnet18')
modelflip = ResNet18a(input_shape=(64, 64, 64, 3),include_top=False, pooling = 'avg',weights=None)
def _untransformed_scale_constraint(t):
    return tf.clip_by_value(t, -1000,
                            tf.math.log(0.2))

kernel_posterior_fn = tfp.layers.default_mean_field_normal_fn(
      untransformed_scale_initializer=tf.compat.v1.initializers.random_normal(
          mean=-9.,
          stddev=0.1),
          untransformed_scale_constraint=_untransformed_scale_constraint)
divergence_fn = lambda q, p, _: tfd.kl_divergence(q, p) / Data_train_length

inputs64 = Input(ma_64.shape+(1,))
x = tf.keras.layers.Lambda(tf.tile, arguments={'multiples':(1,1,1, 1, 3)})(inputs64)
x=modelflip(x)
x = tf.keras.layers.GlobalAveragePooling3D(name='pool1')(x)
x = tfp.layers.DenseFlipout(
 units=tfp.layers.MultivariateNormalTriL.params_size(len_params),
      kernel_posterior_fn=kernel_posterior_fn,kernel_divergence_fn = divergence_fn)(x)
outputbnn=tfp.layers.MultivariateNormalTriL(len_params,convert_to_tensor_fn=tfp.distributions.Distribution.mean)(x)
model3 = Model(inputs64, outputbnn, name="BNNs")
#model3.add_loss(tf.abs(tf.reduce_mean(x)))
model3.summary()
negloglik = lambda y, rv_y: -rv_y.log_prob(y)
#mean_metric = lambda y, rv_y: tf.keras.metrics.mean_squared_error(y, rv_y)

epochs=50*3
adam = tf.optimizers.RMSprop()#,(1e-3)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min' ,factor=0.8,verbose=1,
                              patience=5, min_lr=1e-6)
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15,mode='min',restore_best_weights=True)


model3.compile(optimizer=adam, loss=negloglik ,metrics=['mse'])
model3.fit(
     Train_dataset, epochs=epochs,
           validation_data=Validation_dataset,  callbacks=[reduce_lr,callback],verbose=1)
# model3.load_weights('save_models_jorge4/modelmnfflipresnet18')
# model3.evaluate(Test_dataset)
# Out:
# Model: "BNNs"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 64, 1)]   0
#
#  lambda_1 (Lambda)           (None, 64, 64, 64, 3)     0
#
#  model_1 (Functional)        (None, 2, 2, 2, 512)      33214281
#
#  pool1 (GlobalAveragePooling  (None, 512)              0
#  3D)
#
#  dense_flipout (DenseFlipout  (None, 14)               14350
#  )
#
#  multivariate_normal_tri_l_1  ((None, 4),              0
#   (MultivariateNormalTriL)    (None, 4))
#
# =================================================================
# Total params: 33,228,631
# Trainable params: 33,220,689
# Non-trainable params: 7,942
# _________________________________________________________________
# /opt/conda/lib/python3.7/site-packages/tensorflow_probability/python/layers/util.py:102: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   trainable=trainable)
# /opt/conda/lib/python3.7/site-packages/tensorflow_probability/python/layers/util.py:112: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   trainable=trainable)
# Epoch 1/150
# 2023-05-03 01:56:41.639169: I tensorflow/core/grappler/optimizers/generic_layout_optimizer.cc:370] Cancel Transpose nodes around Pad: transpose_before=BNNs/model_1/bn_data/FusedBatchNormV3-0-0-TransposeNCDHWToNDHWC-LayoutOptimizer pad=BNNs/model_1/zero_padding3d_18/Pad transpose_after=BNNs/model_1/conv0/Conv3D-0-TransposeNDHWCToNCDHW-LayoutOptimizer,gradient_tape/BNNs/model_1/conv0/Conv3D/Conv3DBackpropFilterV2-0-TransposeNDHWCToNCDHW-LayoutOptimizer,gradient_tape/BNNs/model_1/conv0/Conv3D/Shape-0-TransposeNDHWCToNCDHW-LayoutOptimizer
# 186/186 [==============================] - ETA: 0s - loss: 52.8770 - mse: 0.4663
# 2023-05-03 01:57:21.682426: I tensorflow/core/grappler/optimizers/generic_layout_optimizer.cc:370] Cancel Transpose nodes around Pad: transpose_before=BNNs/model_1/bn_data/FusedBatchNormV3-0-0-TransposeNCDHWToNDHWC-LayoutOptimizer pad=BNNs/model_1/zero_padding3d_18/Pad transpose_after=BNNs/model_1/conv0/Conv3D-0-TransposeNDHWCToNCDHW-LayoutOptimizer
# 186/186 [==============================] - 45s 222ms/step - loss: 52.8770 - mse: 0.4663 - val_loss: 6080.1069 - val_mse: 2.0098 - lr: 0.0010
# Epoch 2/150
#  44/186 [======>.......................] - ETA: 30s - loss: 50.9256 - mse: 0.4054
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2645/119648252.py in <module>
#      38 model3.fit(
#      39      Train_dataset, epochs=epochs,
# ---> 40            validation_data=Validation_dataset,  callbacks=[reduce_lr,callback],verbose=1)
#      41 # model3.load_weights('save_models_jorge4/modelmnfflipresnet18')
#      42 # model3.evaluate(Test_dataset)
#
# /opt/conda/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1562                         ):
#    1563                             callbacks.on_train_batch_begin(step)
# -> 1564                             tmp_logs = self.train_function(iterator)
#    1565                             if data_handler.should_sync:
#    1566                                 context.async_wait()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2495        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2496     return graph_function._call_flat(
# -> 2497         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2498
#    2499   @property
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1861       # No tape is watching; skip to running the function.
#    1862       return self._build_call_outputs(self._inference_function.call(
# -> 1863           ctx, args, cancellation_manager=cancellation_manager))
#    1864     forward_backward = self._select_forward_and_backward_functions(
#    1865         args,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
def get_arrays(samples=100):
  prediction_batch=[]
  prediction_batch_std=[]
  prediction_batch_mse=[]
  target_batch=[]
  for x, y_ in Test_dataset:
    y=normalization_features_mean(y_)
    prediction_sample_mean=[]
    prediction_sample_std=[]
    prediction_sample_mse=[]
    ydis = [mnf_lenet(x) for _ in range(samples)]
    for i, y_pred in enumerate(ydis):
      means = normalization_features_mean(np.squeeze(y_pred.mean()))
      mse=tf.math.square(means-y).numpy()
      prediction_sample_mean.append(means)
      prediction_sample_mse.append(mse)
      stds = normalization_features_var(np.squeeze(y_pred.covariance()))
      prediction_sample_std.append(stds)
    prediction_sample_mean_total= np.mean(np.array(prediction_sample_mean),axis=0)
    prediction_sample_mse_total= np.mean(np.array(prediction_sample_mse),axis=0)
    prediction_sample_std_total= np.mean(np.array(prediction_sample_std),axis=0)
    trans=np.transpose(prediction_sample_mean, (1, 2, 0))
    prediction_sample_std_means= np.array([np.cov(x) for x in trans])  
    epis= prediction_sample_std_means+prediction_sample_std_total
    prediction_batch.append(prediction_sample_mean_total)
    prediction_batch_mse.append(prediction_sample_mse_total)
    prediction_batch_std.append(epis)
    target_batch.append(y)
  shaped=np.array(prediction_batch_std).shape
  prediction_mean_ep = np.concatenate(prediction_batch)
  prediction_std_ep = np.concatenate(prediction_batch_std)
  prediction_mse_ep = np.concatenate(prediction_batch_mse)
  target_ep = np.concatenate(target_batch)
  df = pd.DataFrame({'target_ep0':target_ep[:,0],
                   'target_ep1':target_ep[:,1],
                   'target_ep2':target_ep[:,2],
                   'target_ep3':target_ep[:,3],
                   'prediction0':prediction_mean_ep[:,0],
                   'prediction1':prediction_mean_ep[:,1],
                   'prediction2':prediction_mean_ep[:,2],
                   'prediction3':prediction_mean_ep[:,3],
                   'prediction0mse':prediction_mse_ep[:,0],
                   'prediction1mse':prediction_mse_ep[:,1],
                   'prediction2mse':prediction_mse_ep[:,2],
                   'prediction3mse':prediction_mse_ep[:,3],
                   'std0':np.sqrt(prediction_std_ep[:,0,0]),
                   'std1':np.sqrt(prediction_std_ep[:,1,1]),
                   'std2':np.sqrt(prediction_std_ep[:,2,2]),
                   'std3':np.sqrt(prediction_std_ep[:,3,3]),
                   'var0':prediction_std_ep[:,0,0],
                   'var1':prediction_std_ep[:,1,1],
                   'var2':prediction_std_ep[:,2,2],
                   'var3':prediction_std_ep[:,3,3]
                    
                    })

  return df

# %%
df1=get_arrays(samples=1000)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:29: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
df1=pd.read_csv('df1_jorgelastseresnet.csv')

# %%
df1
# Out:
#      target_ep0  target_ep1  target_ep2  target_ep3  prediction0  prediction1  \
# 0      0.110588    0.574370    0.923735    0.551169     0.105792     0.664113
# 1      0.262074    0.842283    0.891123    0.401622     0.298594     0.675971
# 2      0.343142    0.582506    0.663644    0.555849     0.287005     0.669112
# 3      0.144838    0.532485    0.608016    0.580222     0.146868     0.664606
# 4      0.286268    0.772328    0.646773    0.407831     0.305229     0.678479
# ..          ...         ...         ...         ...          ...          ...
# 495    0.475092    0.717916    0.957743    0.402116     0.431095     0.759282
# 496    0.195226    0.590030    0.908806    0.445840     0.209532     0.664498
# 497    0.106916    0.781068    0.705030    0.517460     0.120124     0.664182
# 498    0.408073    0.532638    0.868983    0.460327     0.332041     0.694311
# 499    0.351298    0.825481    0.918671    0.504764     0.392783     0.738207
#
#      prediction2  prediction3  prediction0mse  prediction1mse  prediction2mse  \
# 0       0.872967     0.500355        0.000188        0.008107        0.002842
# 1       0.946576     0.487460        0.001559        0.027727        0.003245
# 2       0.658655     0.515454        0.003308        0.007538        0.000110
# 3       0.618628     0.529487        0.000086        0.017507        0.000136
# 4       0.703625     0.508290        0.000507        0.008874        0.003339
# ..           ...          ...             ...             ...             ...
# 495     1.001748     0.479002        0.002264        0.002068        0.002176
# 496     0.917897     0.492673        0.000365        0.005593        0.000260
# 497     0.686842     0.516868        0.000308        0.013705        0.000689
# 498     0.872880     0.490376        0.006036        0.026269        0.000156
# 499     0.905326     0.485878        0.001909        0.007743        0.000333
#
#      prediction3mse      std0      std1      std2      std3      var0  \
# 0          0.002596  0.034736  0.115066  0.058770  0.056192  0.001207
# 1          0.007376  0.069637  0.119750  0.057757  0.057356  0.004849
# 2          0.001640  0.062736  0.121114  0.038993  0.055877  0.003936
# 3          0.002588  0.032276  0.104956  0.033135  0.048157  0.001042
# 4          0.010099  0.065803  0.120853  0.044544  0.058227  0.004330
# ..              ...       ...       ...       ...       ...       ...
# 495        0.005925  0.060852  0.094770  0.055770  0.054554  0.003703
# 496        0.002201  0.052707  0.119675  0.058362  0.057193  0.002778
# 497        0.000019  0.034383  0.113852  0.050252  0.056254  0.001182
# 498        0.000910  0.070185  0.117407  0.056816  0.059671  0.004926
# 499        0.000365  0.062512  0.102697  0.056182  0.057914  0.003908
#
#          var1      var2      var3
# 0    0.013240  0.003454  0.003157
# 1    0.014340  0.003336  0.003290
# 2    0.014669  0.001520  0.003122
# 3    0.011016  0.001098  0.002319
# 4    0.014606  0.001984  0.003390
# ..        ...       ...       ...
# 495  0.008981  0.003110  0.002976
# 496  0.014322  0.003406  0.003271
# 497  0.012962  0.002525  0.003165
# 498  0.013784  0.003228  0.003561
# 499  0.010547  0.003156  0.003354
#
# [500 rows x 20 columns]

# %%
exple=1
#plt.errorbar(df1['target_ep1'][:200], df1['prediction1'][:200], yerr =np.sqrt(df1['var1'][:200]), ecolor = 'lightgreen',  capsize=10,fmt = '.', color = 'orange')
df1a=df1.sample(100)
#plt.scatter(df1a['target_ep0'][:], df1a['prediction0'][:])
plt.errorbar(df1a['target_ep3'], df1a['prediction3'][:], yerr =np.sqrt(df1a['var3'][:]), ecolor = 'lightgreen',  capsize=10,fmt = '.', color = 'orange')
plt.xlabel(r"True $f(R)$")
plt.ylabel(r"Predicted $f(R)$")
#plt.savefig("plotjorge/fr.png")
plt.show()

# %%
exple=1
#df1=pd.read_csv("df1_jorgelastseresnet.csv")
#params=['Om', 'h', 'sigma8', 'fR0_scaled']
#plt.errorbar(df1['target_ep1'][:200], df1['prediction1'][:200], yerr =np.sqrt(df1['var1'][:200]), ecolor = 'lightgreen',  capsize=10,fmt = '.', color = 'orange')
df1a=df1.sample(200)
import matplotlib 
matplotlib.rc('xtick', labelsize=18) 
matplotlib.rc('ytick', labelsize=18) 
plt.rcParams.update({'font.size': 18})

# %%
#plt.scatter(df1a['target_ep0'][:], df1a['prediction0'][:])
#xt=np.linspace(df1a.target_ep3.min(), df1a.target_ep3.max(), 15)
#plt.errorbar(df1a['target_ep3'], df1a['prediction3'][:], yerr =np.sqrt(df1a['var3'][:]), ecolor = 'lightblue',  capsize=10,fmt = '.', color = 'blue')
xt=np.linspace(df1a.target_ep3.min(), df1a.target_ep3.max(), 15)
plt.errorbar(df1a['target_ep3'], df1a['prediction3'][:], yerr =np.sqrt(df1a['var3'][:]), ecolor = 'lightblue',  capsize=10,fmt = '.', color = 'blue')
plt.plot(xt,xt,alpha=0.1,label='perfect match',color='black')
plt.xlabel(r"True $f_{R0}$")
plt.ylabel(r"Predicted $f_{R0}$")
plt.legend(loc=2, prop={'size': 13})
#plt.show()
plt.savefig("plotjorge/frnew.png", bbox_inches='tight')

# %%
df1.to_csv('df1_jorgelast.csv', index=False)

# %%
# !pwd
# Out:
# /home/jupyter/tf-mnf/notebooks

# %%
df1a=df1.sort_values(by=['var1'])

# %%
bins1 = np.linspace(df1a.var1.min(), df1a.var1.max(), 10)

# %%
groups1 = df1a.groupby(np.digitize(df1a.var1, bins1))

# %%
xt=np.linspace(df1a.var1.min(), df1a.var1.max(), 15)
plt.plot(groups1.mean().var1,groups1.mean().prediction1mse)
#plt.plot(groups5.mean().var0[0:-1],groups5.mean().prediction0mse[0:-1])
plt.plot(xt,xt)

# %%
# %matplotlib inline
import getdist
from getdist import plots, MCSamples
import matplotlib.pyplot as plt
for x, y_ in Test_dataset.take(5):
  y =normalization_features_mean(y_) 
  prediction_sample_mean=[]
  prediction_sample_std=[]
  valu_real=y
  samples_= mnf_lenet(x).sample(10000)
  samples_=normalization_features_mean(samples_)
  #samples_flip= model3(x).sample(10000)
  #samples_flip=normalization_features_mean(samples_flip)   
names = ["x%s"%i for i in range(4)]
labels =  ['\Omega_m','h','\sigma_8','f_{R0}']

# %%
g = plots.get_subplot_plotter()
g.triangle_plot([samples_], ['x0', 'x1', 'x2','x3'], filled=True, 
                #upper_roots = [samples2],
                #upper_kwargs = {'contour_colors':['green']}, 
                legend_labels=['Samples','Reweighted samples','Second samples']);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_21488/2330848981.py in <module>
#       3                 #upper_roots = [samples2],
#       4                 #upper_kwargs = {'contour_colors':['green']},
# ----> 5                 legend_labels=['Samples','Reweighted samples','Second samples']);
#
# /opt/conda/lib/python3.7/site-packages/getdist/plots.py in triangle_plot(self, roots, params, legend_labels, plot_3d_with_param, filled, shaded, contour_args, contour_colors, contour_ls, contour_lws, line_args, label_order, legend_ncol, legend_loc, title_limit, upper_roots, upper_kwargs, upper_label_right, diag1d_kwargs, markers, marker_args, param_limits, **kwargs)
#    2355         """
#    2356         roots = makeList(roots)
# -> 2357         params = self.get_param_array(roots[0], params)
#    2358         plot_col = len(params)
#    2359         if plot_3d_with_param is not None:
#
# /opt/conda/lib/python3.7/site-packages/getdist/plots.py in get_param_array(self, root, params, renames)
#    1781             names = ParamNames(names=root.names, default=getattr(root, 'dim', 0))
#    1782         else:
# -> 1783             names = self.param_names_for_root(root)
#    1784
#    1785         if params is None or len(params) == 0:
#
# /opt/conda/lib/python3.7/site-packages/getdist/plots.py in param_names_for_root(self, root)
#     906         :return: :class:`~.paramnames.ParamNames` instance
#     907         """
# --> 908         if root not in self.param_name_sets:
#     909             self.param_name_sets[root] = \
#     910                 self.sample_analyser.params_for_root(root, label_params=self.settings.param_names_for_labels)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in __hash__(self)
#     899     if (Tensor._USE_EQUALITY and executing_eagerly_outside_functions() and
#     900         (g is None or g.building_function)):
# --> 901       raise TypeError("Tensor is unhashable. "
#     902                       "Instead, use tensor.ref() as the key.")
#     903     else:
#
# TypeError: Tensor is unhashable. Instead, use tensor.ref() as the key.

# %%
n_instance=2
#!pip install getdist
samples = MCSamples(samples=samples_.numpy()[:,n_instance,:],names = names, labels = labels)
#samplesflip = MCSamples(samples=samples_flip.numpy()[:,n_instance,:],names = names, labels = labels)
y_0=y[n_instance][0].numpy()
y_1=y[n_instance][1].numpy()
y_2=y[n_instance][2].numpy()
y_3=y[n_instance][3].numpy()
p=samples.getParams()
#pf=samplesflip.getParams()
samples.addDerived(p.x0**(0.25)*p.x2, name='x4', label='\sigma_8\Omega_m^{0.25}', range=[0,None])
samples.addDerived(p.x0*p.x1**2, name='x5', label='\Omega_m h^{2}', range=[0,None])
#samplesflip.addDerived(pf.x0**(0.25)*pf.x1, name='x3', label='\sigma_8\Omega_m^{0.25}', range=[0,None])
#samplesflip.addDerived(pf.x0*pf.x2**2, name='x4', label='\Omega_m h^{2}', range=[0,None])
g = plots.get_subplot_plotter()
g.settings.title_limit_fontsize = 18
g.settings.axes_labelsize =20
g.triangle_plot(samples, filled=True,
                #upper_roots = [samplesflip],
                #upper_kwargs = {'contour_colors':['green']},
                legend_labels=['VBNNs'],legend_loc='lower center',
                markers={'x0':y_0,'x1': y_1,'x2': y_2,'x3':y_3,'x4': y_0**(0.25)*y_2,'x5': y_0*y_1**2})
g.export('plotorge/triangular_plot_vbb.pdf')
# Out:
# Removed no burn in

# %%
print(samples.getTable().tableTex())
# Out:
# \begin{tabular} { l  c}
#
#  Parameter &  95\% limits\\
# \hline
# {\boldmath$\Omega_m       $} & $0.471^{+0.087}_{-0.084}   $\\
#
# {\boldmath$h              $} & $0.82^{+0.16}_{-0.17}      $\\
#
# {\boldmath$\sigma_8       $} & $0.797^{+0.091}_{-0.092}   $\\
#
# {\boldmath$f_{R_0}        $} & $0.49^{+0.12}_{-0.12}      $\\
#
# $\sigma_8\Omega_m^{0.25}   $ & $0.659^{+0.082}_{-0.079}   $\\
#
# $\Omega_m h^{2}            $ & $0.32^{+0.13}_{-0.12}      $\\
# \hline
# \end{tabular}

# %%
print(samplesflip.getTable().tableTex())
# Out:
# \begin{tabular} { l  c}
#
#  Parameter &  95\% limits\\
# \hline
# {\boldmath$\Omega_m       $} & $0.45^{+0.11}_{-0.11}      $\\
#
# {\boldmath$\sigma_8       $} & $0.699^{+0.059}_{-0.060}   $\\
#
# {\boldmath$h              $} & $0.78^{+0.20}_{-0.19}      $\\
#
# $\sigma_8\Omega_m^{0.25}   $ & $0.573^{+0.063}_{-0.064}   $\\
#
# $\Omega_m h^{2}            $ & $0.28^{+0.13}_{-0.12}      $\\
# \hline
# \end{tabular}

# %%
y[n_instance]
# Out:
# <tf.Tensor: shape=(4,), dtype=float64, numpy=array([0.44047085, 0.86613123, 0.82503636, 0.52745052])>

# %%
 y_0**(0.25)*y_1, y_0*y_2**2
# Out:
# (0.7056071778063038, 0.29982189525478725)

# %%
from uncertainties import ufloat

# %%
def omegalow(x):
    omega0= ufloat(x["prediction0"], x["std0"])
    hparam= ufloat(x["prediction1"], x["std1"])
    omelow=omega0*hparam**2
    return omelow.n, omelow.s
def omegasig(x):
    omega0= ufloat(x["prediction0"], x["std0"])
    sigma= ufloat(x["prediction2"], x["std2"])
    omelow=sigma*omega0**0.25
    return omelow.n, omelow.s

# %%
df1.head()
# Out:
#    target_ep0  target_ep1  target_ep2  target_ep3  prediction0  prediction1  \
# 0    0.110588    0.574370    0.923735    0.551169     0.105792     0.664113
# 1    0.262074    0.842283    0.891123    0.401622     0.298594     0.675971
# 2    0.343142    0.582506    0.663644    0.555849     0.287005     0.669112
# 3    0.144838    0.532485    0.608016    0.580222     0.146868     0.664606
# 4    0.286268    0.772328    0.646773    0.407831     0.305229     0.678479
#
#    prediction2  prediction3  prediction0mse  prediction1mse  ...      std1  \
# 0     0.872967     0.500355        0.000188        0.008107  ...  0.115066
# 1     0.946576     0.487460        0.001559        0.027727  ...  0.119750
# 2     0.658655     0.515454        0.003308        0.007538  ...  0.121114
# 3     0.618628     0.529487        0.000086        0.017507  ...  0.104956
# 4     0.703625     0.508290        0.000507        0.008874  ...  0.120853
#
#        std2      std3      var0      var1      var2      var3  omegalowtrue  \
# 0  0.058770  0.056192  0.001207  0.013240  0.003454  0.003157      0.036483
# 1  0.057757  0.057356  0.004849  0.014340  0.003336  0.003290      0.185926
# 2  0.038993  0.055877  0.003936  0.014669  0.001520  0.003122      0.116433
# 3  0.033135  0.048157  0.001042  0.011016  0.001098  0.002319      0.041068
# 4  0.044544  0.058227  0.004330  0.014606  0.001984  0.003390      0.170756
#
#    omegalowmean  omegalowstd
# 0      0.046659     0.022274
# 1      0.136438     0.057874
# 2      0.128495     0.054339
# 3      0.064872     0.024961
# 4      0.140507     0.058507
#
# [5 rows x 23 columns]

# %%
df1[["omegalowmean","omegalowstd"]]=df1.apply(lambda x: omegalow(x),axis=1, result_type="expand")

# %%
df1["omegalowtrue"]=df1["target_ep0"]*df1["target_ep1"]**2

# %%
df1["omegasigmatrue"]=df1["target_ep2"]*df1["target_ep0"]**0.25

# %%
df1[["omegasigmamean","omegasigmastd"]]=df1.apply(lambda x: omegasig(x),axis=1, result_type="expand")

# %%
import pandas as pd

# %%
df1=pd.read_csv("/home/jupyter/tf-mnf/notebooks/tf-mnf/logs3D_exp/seresnet18/df/df1mpdifyy.csv")

# %%
df2=pd.read_csv("/home/jupyter/tf-mnf/notebooks/tf-mnf/logs3D_exp/seresnet18/df/df1.csv")

# %%
dffer1=df1[["target_ep0" ,"target_ep1" ,"target_ep2" ,"target_ep3"]]

# %%
dffer2=df2[["target_ep0" ,"target_ep1" ,"target_ep2" ,"target_ep3"]]

# %%
params=['Om', 'h', 'sigma8', 'fR0_scaled']
data = pd.read_csv('jorge/jorge/latin_hypercube_params.txt', sep="\s", header=0)
data[params]
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#             Om         h    sigma8  fR0_scaled
# 0     0.319057  0.621471  0.659495    0.567758
# 1     0.225592  0.812328  0.717481    0.536195
# 2     0.377067  0.533253  0.686238    0.418775
# 3     0.167260  0.727625  0.884341    0.531757
# 4     0.225614  0.810414  0.621485    0.437325
# ...        ...       ...       ...         ...
# 2495  0.339336  0.559396  0.742226    0.550448
# 2496  0.122572  0.644170  0.711846    0.533910
# 2497  0.420556  0.868666  0.672555    0.415639
# 2498  0.344678  0.605431  0.664767    0.446232
# 2499  0.264797  0.645144  0.951746    0.513390
#
# [2500 rows x 4 columns]

# %%
sa1=dffer1.merge(dffer2, how='inner', on=["target_ep0" ,"target_ep1" ,"target_ep2" ,"target_ep3"])

# %%
sa2=df1.merge(data, how='inner', left_on=["target_ep0" ,"target_ep1" ,"target_ep2" ,"target_ep3"],right_on=params)

# %%
data[data["Om"]==0.475092]
# Out:
# Empty DataFrame
# Columns: [index, Om, h, sigma8, fR0_scaled, fR0_sim]
# Index: []

# %%
df1
# Out:
#      target_ep0  target_ep1  target_ep2  target_ep3  prediction0  prediction1  \
# 0      0.110588    0.574370    0.923735    0.551169     0.149157     0.662619
# 1      0.262074    0.842283    0.891123    0.401622     0.403041     0.731903
# 2      0.343142    0.582506    0.663644    0.555849     0.349927     0.702197
# 3      0.144838    0.532485    0.608016    0.580222     0.169501     0.668628
# 4      0.286268    0.772328    0.646773    0.407831     0.381278     0.723642
# ..          ...         ...         ...         ...          ...          ...
# 495    0.475092    0.717916    0.957743    0.402116     0.499575     0.804033
# 496    0.195226    0.590030    0.908806    0.445840     0.290590     0.674461
# 497    0.106916    0.781068    0.705030    0.517460     0.126544     0.671575
# 498    0.408073    0.532638    0.868983    0.460327     0.426362     0.750261
# 499    0.351298    0.825481    0.918671    0.504764     0.473814     0.788501
#
#      prediction2  prediction3  prediction0mse  prediction1mse  prediction2mse  \
# 0       0.943987     0.491983        0.001635        0.007850        0.000655
# 1       1.021941     0.479370        0.020081        0.012335        0.017339
# 2       0.708928     0.505311        0.000185        0.014405        0.002147
# 3       0.620602     0.525595        0.000680        0.018583        0.000201
# 148     0.767850     0.505181        0.000480        0.012042  ...  0.003456
# 149     0.936660     0.483664        0.000491        0.047496  ...  0.002824
# 150     0.979606     0.478978        0.015165        0.001535  ...  0.002671
#
#          var3  index        Om         h    sigma8  fR0_scaled   fR0_sim  \
# 0    0.003399   2056  0.386520  0.607452  0.702219    0.555722  0.000003
# 1    0.003368    496  0.111021  0.692867  0.799997    0.524332  0.000006
# 2    0.003427    544  0.366745  0.788690  0.783655    0.411526  0.000077
# 3    0.003842    743  0.254602  0.581639  0.743514    0.459273  0.000026
# 4    0.002908    497  0.392238  0.546129  0.612911    0.537695  0.000004
# ..        ...    ...       ...       ...       ...         ...       ...
# 146  0.002984   1256  0.494993  0.886321  0.642618    0.569154  0.000002
# 147  0.003032    927  0.111599  0.543966  0.980454    0.542767  0.000004
# 148  0.003433   2423  0.106916  0.781068  0.705030    0.517460  0.000007
# 149  0.003216   1973  0.408073  0.532638  0.868983    0.460327  0.000025
# 150  0.003034   2278  0.351298  0.825481  0.918671    0.504764  0.000009
#
#      filename                                      filename_path
# 0        2056  jorge/jorge/density_field_latin_hypercube/2056...
# 1         496  jorge/jorge/density_field_latin_hypercube/496/...
# 2         544  jorge/jorge/density_field_latin_hypercube/544/...
# 3         743  jorge/jorge/density_field_latin_hypercube/743/...
# 4         497  jorge/jorge/density_field_latin_hypercube/497/...
# ..        ...                                                ...
# 146      1256  jorge/jorge/density_field_latin_hypercube/1256...
# 147       927  jorge/jorge/density_field_latin_hypercube/927/...
# 148      2423  jorge/jorge/density_field_latin_hypercube/2423...
# 149      1973  jorge/jorge/density_field_latin_hypercube/1973...
# 150      2278  jorge/jorge/density_field_latin_hypercube/2278...
#
# [151 rows x 28 columns]

# %%
sa2.to_csv("labels_test.csv")

# %%
n_instance=2
#!pip install getdist
samples = MCSamples(samples=samples_.numpy()[:,n_instance,:],names = names, labels = labels)
#samplesflip = MCSamples(samples=samples_flip.numpy()[:,n_instance,:],names = names, labels = labels)
# y_0=y[n_instance][0].numpy()
# y_1=y[n_instance][1].numpy()
# y_2=y[n_instance][2].numpy()
# y_3=y[n_instance][3].numpy()
# p=samples.getParams()
# #pf=samplesflip.getParams()
# samples.addDerived(p.x0**(0.25)*p.x2, name='x4', label='\sigma_8\Omega_m^{0.25}', range=[0,None])
# samples.addDerived(p.x0*p.x1**2, name='x5', label='\Omega_m h^{2}', range=[0,None])
#samplesflip.addDerived(pf.x0**(0.25)*pf.x1, name='x3', label='\sigma_8\Omega_m^{0.25}', range=[0,None])
#samplesflip.addDerived(pf.x0*pf.x2**2, name='x4', label='\Omega_m h^{2}', range=[0,None])
g = plots.get_subplot_plotter()
g.settings.title_limit_fontsize = 18
g.settings.axes_labelsize =20
g.triangle_plot(samples, filled=True,
                #upper_roots = [samplesflip],
                #upper_kwargs = {'contour_colors':['green']},
                legend_labels=['VBNNs'],legend_loc='lower center',
                markers={'x0':y_0,'x1': y_1,'x2': y_2,'x3':y_3,'x4': y_0**(0.25)*y_2,'x5': y_0*y_1**2})
g.export('plotorge/triangular_plot_vbb.pdf')
